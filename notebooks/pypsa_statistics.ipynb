# %% [markdown]
# # PyPSA Statistics Module Training
#
# A guided ~40-min session exploring `n.statistics` — PyPSA's high-level API for
# querying costs, capacities, energy flows, and market metrics from optimized networks.
#
# We use `pypsa.examples.carbon_management()`, a sector-coupled European energy system
# from a [Nature Energy paper](https://www.nature.com/articles/s41560-025-01752-6) on
# H₂/CO₂ network strategies (2164 buses, 89 carriers, 20 days at 3h resolution).

# %% [markdown]
# # Motivation
#
# Imagine a collegue sends you a pypsa network, that you should inspect.... things that you might want to do in the start is **understanding** the network.

# %%
import pypsa
import pandas as pd

n = pypsa.examples.carbon_management()
# Out:
# INFO:pypsa.network.io:Imported network 'Hybrid Scenario from https://www.nature.com/articles/s41560-025-01752-6' has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n
# Out:
# PyPSA Network 'Hybrid Scenario from https://www.nature.com/articles/s41560-025-01752-6'
# ---------------------------------------------------------------------------------------
# Components:
#  - Bus: 2164
#  - Carrier: 89
#  - Generator: 1489
#  - GlobalConstraint: 4
#  - Line: 157
#  - Link: 6830
#  - Load: 1357
#  - StorageUnit: 106
#  - Store: 1263
# Snapshots: 168

# %%
n.buses.carrier.value_counts()
# Out:
# carrier
# heat                          450
# water tanks                   450
# AC                             91
# co2 stored                     90
# co2 sequestered                90
# gas                            90
# H2                             90
# battery                        90
# Li ion                         90
# biogas                         90
# solid biomass                  90
# solid biomass for industry     90
# gas for industry               90
# process emissions              90
# low voltage                    90
# home battery                   90
# co2                             1
# methanol                        1
# oil                             1
# Name: count, dtype: int64

# %% [markdown]
# :::{hint} Potential Chain of Thought
# *How should I inspect this? there is so much going on...*
#
# *Okay, let's start with `n.generators.p_nom.groupby(n.generators.carrier)` and then do that for links*
#
# *and then stores - ahh(!) stores have a different attribute `n.stores.e_nom`*
#
# *Ah wait it is `p_nom_opt` / `e_nom_opt` anyway that I should look into......*
# :::
#
# Then you realize, you've been there multiple times and you remember that this can be cumbersome, often error-prone and verbose.
#
# This is why we created the **statistics** module.

# %% [markdown]
# # Statistics Module
#
#
# The **summary table** `n.statistics()` gives a quick overview of all metrics at once.

# %%
n.statistics()
# Out:
#                          Optimal Capacity  Installed Capacity        Supply  \
# Generator Biomass            9.000000e+05        9.000000e+05  7.078587e+06
#           Gas                3.986688e+07        3.986688e+07  2.019385e+07
#           Heat Waste         0.000000e+00        0.000000e+00  0.000000e+00
#           Nuclear            2.884290e+04        2.884290e+04  1.204152e+07
#           Offshore Wind      2.840745e+05        2.499295e+04  6.139897e+07
# ...                                   ...                 ...           ...
# Store     Home Battery       1.034480e+00        0.000000e+00  1.019370e+01
#           Li Ion             6.401152e+06        6.401152e+06  2.871342e+07
#           Methanol           5.083299e+09        0.000000e+00  0.000000e+00
#           Oil                1.090363e+10        0.000000e+00  0.000000e+00
#           Water Tanks        5.255226e+07        0.000000e+00  8.814771e+06
#
#                            Withdrawal  Energy Balance  Transmission  \
# Generator Biomass        0.000000e+00    7.078587e+06           0.0
#           Gas            0.000000e+00    2.019385e+07           0.0
#           Heat Waste     0.000000e+00    0.000000e+00           0.0
#           Nuclear        0.000000e+00    1.204152e+07           0.0
#           Offshore Wind  0.000000e+00    6.139897e+07           0.0
# ...                               ...             ...           ...
# Store     Home Battery   1.020875e+01   -1.505000e-02           0.0
#           Li Ion         2.843394e+07    2.794813e+05           0.0
#           Methanol       7.702488e+06   -7.702488e+06           0.0
#           Oil            1.949353e+06   -1.949353e+06           0.0
#           Water Tanks    1.167123e+07   -2.856458e+06           0.0
#
#                          Capacity Factor   Curtailment  Capital Expenditure  \
# Generator Biomass               0.015605  4.465214e+08         0.000000e+00
#           Gas                   0.001005  2.007271e+10         0.000000e+00
#           Heat Waste            0.000000  0.000000e+00         0.000000e+00
#           Nuclear               0.828346  3.936798e+05         2.038537e+10
#           Offshore Wind         0.428843  1.061900e+04         5.486001e+10
# ...                                  ...           ...                  ...
# Store     Home Battery          0.495031  0.000000e+00         1.135182e+04
#           Li Ion                0.848809  0.000000e+00         0.000000e+00
#           Methanol              0.987076  0.000000e+00         0.000000e+00
#           Oil                   0.998036  0.000000e+00         0.000000e+00
#           Water Tanks           0.077215  0.000000e+00         3.420888e+09
#
#                          Operational Expenditure       Revenue  Market Value
# Generator Biomass                   2.788895e+08  6.670565e+08     94.235825
#           Gas                       4.060941e+08  4.060940e+08     20.109791
#           Heat Waste                0.000000e+00  0.000000e+00           NaN
#           Nuclear                   1.371356e+08  3.444629e+08     28.606267
#           Offshore Wind             1.549022e+06  1.678349e+09     27.335129
# ...                                          ...           ...           ...
# Store     Home Battery             -1.500000e-04  7.939043e+01      0.307596
#           Li Ion                    2.776449e+03  1.051074e+08      0.038383
#           Methanol                 -6.944147e+04 -2.160481e+08     -0.000085
#           Oil                      -2.022049e+04 -3.907728e+07     -0.000007
#           Water Tanks              -2.887862e+04 -8.379614e+06     -0.004097
#
# [87 rows x 12 columns]

# %% [markdown]
# `n.statistics` provides a consistent, high-level API that handles component iteration, port mapping, and carrier grouping automatically.
#
# :::{tip}
# `n.stats` is available as a shorthand alias for `n.statistics`.
# :::
#
# Each method can be called individually or explored via the summary table:
#
# | Category | Methods |
# |---|---|
# | **Costs** | `capex()`, `installed_capex()`, `expanded_capex()`, `opex()`, `system_cost()` |
# | **Capacity** | `installed_capacity()`, `optimal_capacity()`, `expanded_capacity()`, `capacity_factor()` |
# | **Energy** | `supply()`, `withdrawal()`, `energy_balance()`, `transmission()`, `curtailment()` |
# | **Market** | `prices()`, `revenue()`, `market_value()` |
#
# Every method accepts the same filtering and grouping parameters:
#
# | Parameter | Description |
# |---|---|
# | `groupby` | String, list, or callable — how to group results (default: `"carrier"`) |
# | `groupby_method` | Aggregation function (`"sum"` (default), `"mean"`, …) |
# | `groupby_time` | `"sum"`, `"mean"`, or `False` for time series — default varies by method |
# | `components` | Filter to specific component types |
# | `carrier` | Filter by carrier name (internal name) |
# | `bus_carrier` | Filter by the carrier of the bus |
# | `nice_names` | Use human-readable carrier names (default: `True`) |
#
# :::{warning}
# `prices()` has a simplified interface — `groupby` and `groupby_time` are booleans,
# and it does not accept `carrier` or `components`.
# :::
#
# That's a lot of info, let's see it in action!

# %% [markdown]
# # Cost Analysis
#
# Three cost methods form a hierarchy:
#
# :::{note} Cost hierarchy
# - **capex** = `installed_capex` + `expanded_capex` (capital costs)
# - **opex** (operational costs)
# - **system_cost** = capex + opex (total)
# :::

# %%
capex = n.statistics.capex() # returns a series
capex.to_frame("capex")
# Out:
#                                                       capex
# component   carrier
# Generator   Nuclear                            2.038537e+10
#             Offshore Wind                      5.486001e+10
#             Onshore Wind                       1.305322e+11
#             Run Of River                       1.420496e+10
#             Solar                              1.329792e+11
#             Solar Rooftop                      1.744765e+10
#             Solar Thermal                      2.260486e+09
# Line        AC                                 1.428499e+10
# Link        Air Heat Pump                      3.770428e+10
#             Allam Cycle                        9.736585e+03
#             Battery Charger                    2.816038e+09
#             Biogas To Gas                      3.265524e+04
#             Biogas To Gas CC                   9.249432e+09
#             Biomass Boiler                     3.562358e+09
#             Biomass CHP                        1.297272e+04
#             Biomass CHP CC                     1.464221e+10
#             Biomass-based Industry Process CC  8.398548e+09
#             CO$_2$ Pipeline                    6.346290e+08
#             DAC                                1.124051e+10
#             DC                                 8.421211e+08
#             Electricity Distribution Grid      3.792129e+10
#             Fischer-Tropsch                    1.173604e+10
#             Gas Boiler                         1.041957e+10
#             Gas CHP                            4.890731e+09
#             Gas CHP CC                         1.087935e+04
#             Gas Pipeline                       8.797224e+09
#             Gas Pipeline New                   3.772032e+06
#             Gas-based Industry Process CC      2.464650e+09
#             Ground Heat Pump                   2.472317e+10
#             H$_2$ Electrolysis                 3.507251e+10
#             H$_2$ Fuel Cell                    9.695602e+03
#             H$_2$ Pipeline                     1.254016e+09
#             Home Battery Charger               1.203474e+04
#             Methanation                        3.282494e+09
#             Methanolisation                    5.463875e+09
#             Open-Cycle Gas                     1.215088e+09
#             Process Emission CC                4.441256e+09
#             Resistive Heater                   2.137661e+09
#             SMR                                4.966509e+03
#             SMR CC                             6.389109e+03
# StorageUnit Pumped Hydro Storage               9.764073e+09
#             Reservoir & Dam                    1.655813e+10
# Store       Battery Storage                    8.529886e+09
#             CO$_2$ Sequestration               2.000000e+09
#             CO$_2$ Stored                      3.089380e+08
#             Gas                                7.173411e+10
#             H$_2$ Storage                      6.375581e+09
#             Home Battery                       1.135182e+04
#             Water Tanks                        3.420888e+09

# %%
opex = n.statistics.opex()
opex.head(10).to_frame("opex")
# Out:
#                                  opex
# component carrier
# Generator Biomass        2.788895e+08
#           Gas            4.060941e+08
#           Nuclear        1.371356e+08
#           Offshore Wind  1.549022e+06
#           Oil            6.590160e+00
#           Onshore Wind   3.378577e+06
#           Run Of River   1.527416e+05
#           Solar          5.589634e+06
#           Solar Rooftop  8.267070e+05
#           Solar Thermal  6.264980e+04

# %%
system_cost = n.statistics.system_cost()
print(f"Total system cost: {system_cost.sum() / 1e9:.1f} bn €")
# Out:
# Total system cost: 750.9 bn €

# %% [markdown]
# The `groupby_method` parameter controls how values are aggregated within each group.
# Compare `"sum"` (default, total) vs `"mean"` (average per asset). Let's also use pandas `.style` accessor for better cost formatting.

# %%
costs = pd.concat([
    n.statistics.capex(groupby_method="sum").rename("sum"),
    n.statistics.capex(groupby_method="mean").rename("mean"),
], axis=1)
    
costs.sort_values(by="sum", ascending=False).div(1e6).style.format("{:,.0f} M€")
# Out:
# <style type="text/css">
# </style>
# <table id="T_334bd">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_334bd_level0_col0" class="col_heading level0 col0" >sum</th>
#       <th id="T_334bd_level0_col1" class="col_heading level0 col1" >mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >component</th>
#       <th class="index_name level1" >carrier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_334bd_level0_row0" class="row_heading level0 row0" rowspan="2">Generator</th>
#       <th id="T_334bd_level1_row0" class="row_heading level1 row0" >Solar</th>
#       <td id="T_334bd_row0_col0" class="data row0 col0" >132,979 M€</td>
#       <td id="T_334bd_row0_col1" class="data row0 col1" >1,478 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level1_row1" class="row_heading level1 row1" >Onshore Wind</th>
#       <td id="T_334bd_row1_col0" class="data row1 col0" >130,532 M€</td>
#       <td id="T_334bd_row1_col1" class="data row1 col1" >1,450 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row2" class="row_heading level0 row2" >Store</th>
#       <th id="T_334bd_level1_row2" class="row_heading level1 row2" >Gas</th>
#       <td id="T_334bd_row2_col0" class="data row2 col0" >71,734 M€</td>
#       <td id="T_334bd_row2_col1" class="data row2 col1" >797 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row3" class="row_heading level0 row3" >Generator</th>
#       <th id="T_334bd_level1_row3" class="row_heading level1 row3" >Offshore Wind</th>
#       <td id="T_334bd_row3_col0" class="data row3 col0" >54,860 M€</td>
#       <td id="T_334bd_row3_col1" class="data row3 col1" >508 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row4" class="row_heading level0 row4" rowspan="4">Link</th>
#       <th id="T_334bd_level1_row4" class="row_heading level1 row4" >Electricity Distribution Grid</th>
#       <td id="T_334bd_row4_col0" class="data row4 col0" >37,921 M€</td>
#       <td id="T_334bd_row4_col1" class="data row4 col1" >421 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level1_row5" class="row_heading level1 row5" >Air Heat Pump</th>
#       <td id="T_334bd_row5_col0" class="data row5 col0" >37,704 M€</td>
#       <td id="T_334bd_row5_col1" class="data row5 col1" >140 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level1_row6" class="row_heading level1 row6" >H$_2$ Electrolysis</th>
#       <td id="T_334bd_row6_col0" class="data row6 col0" >35,073 M€</td>
#       <td id="T_334bd_row6_col1" class="data row6 col1" >390 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level1_row7" class="row_heading level1 row7" >Ground Heat Pump</th>
#       <td id="T_334bd_row7_col0" class="data row7 col0" >24,723 M€</td>
#       <td id="T_334bd_row7_col1" class="data row7 col1" >137 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row8" class="row_heading level0 row8" rowspan="2">Generator</th>
#       <th id="T_334bd_level1_row8" class="row_heading level1 row8" >Nuclear</th>
#       <td id="T_334bd_row8_col0" class="data row8 col0" >20,385 M€</td>
#       <td id="T_334bd_row8_col1" class="data row8 col1" >1,699 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level1_row9" class="row_heading level1 row9" >Solar Rooftop</th>
#       <td id="T_334bd_row9_col0" class="data row9 col0" >17,448 M€</td>
#       <td id="T_334bd_row9_col1" class="data row9 col1" >194 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row10" class="row_heading level0 row10" >StorageUnit</th>
#       <th id="T_334bd_level1_row10" class="row_heading level1 row10" >Reservoir & Dam</th>
#       <td id="T_334bd_row10_col0" class="data row10 col0" >16,558 M€</td>
#       <td id="T_334bd_row10_col1" class="data row10 col1" >312 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row11" class="row_heading level0 row11" >Link</th>
#       <th id="T_334bd_level1_row11" class="row_heading level1 row11" >Biomass CHP CC</th>
#       <td id="T_334bd_row11_col0" class="data row11 col0" >14,642 M€</td>
#       <td id="T_334bd_row11_col1" class="data row11 col1" >163 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row12" class="row_heading level0 row12" >Line</th>
#       <th id="T_334bd_level1_row12" class="row_heading level1 row12" >AC</th>
#       <td id="T_334bd_row12_col0" class="data row12 col0" >14,285 M€</td>
#       <td id="T_334bd_row12_col1" class="data row12 col1" >91 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row13" class="row_heading level0 row13" >Generator</th>
#       <th id="T_334bd_level1_row13" class="row_heading level1 row13" >Run Of River</th>
#       <td id="T_334bd_row13_col0" class="data row13 col0" >14,205 M€</td>
#       <td id="T_334bd_row13_col1" class="data row13 col1" >233 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row14" class="row_heading level0 row14" rowspan="3">Link</th>
#       <th id="T_334bd_level1_row14" class="row_heading level1 row14" >Fischer-Tropsch</th>
#       <td id="T_334bd_row14_col0" class="data row14 col0" >11,736 M€</td>
#       <td id="T_334bd_row14_col1" class="data row14 col1" >130 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level1_row15" class="row_heading level1 row15" >DAC</th>
#       <td id="T_334bd_row15_col0" class="data row15 col0" >11,241 M€</td>
#       <td id="T_334bd_row15_col1" class="data row15 col1" >62 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level1_row16" class="row_heading level1 row16" >Gas Boiler</th>
#       <td id="T_334bd_row16_col0" class="data row16 col0" >10,420 M€</td>
#       <td id="T_334bd_row16_col1" class="data row16 col1" >23 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row17" class="row_heading level0 row17" >StorageUnit</th>
#       <th id="T_334bd_level1_row17" class="row_heading level1 row17" >Pumped Hydro Storage</th>
#       <td id="T_334bd_row17_col0" class="data row17 col0" >9,764 M€</td>
#       <td id="T_334bd_row17_col1" class="data row17 col1" >184 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row18" class="row_heading level0 row18" rowspan="2">Link</th>
#       <th id="T_334bd_level1_row18" class="row_heading level1 row18" >Biogas To Gas CC</th>
#       <td id="T_334bd_row18_col0" class="data row18 col0" >9,249 M€</td>
#       <td id="T_334bd_row18_col1" class="data row18 col1" >103 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level1_row19" class="row_heading level1 row19" >Gas Pipeline</th>
#       <td id="T_334bd_row19_col0" class="data row19 col0" >8,797 M€</td>
#       <td id="T_334bd_row19_col1" class="data row19 col1" >18 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row20" class="row_heading level0 row20" >Store</th>
#       <th id="T_334bd_level1_row20" class="row_heading level1 row20" >Battery Storage</th>
#       <td id="T_334bd_row20_col0" class="data row20 col0" >8,530 M€</td>
#       <td id="T_334bd_row20_col1" class="data row20 col1" >95 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row21" class="row_heading level0 row21" >Link</th>
#       <th id="T_334bd_level1_row21" class="row_heading level1 row21" >Biomass-based Industry Process CC</th>
#       <td id="T_334bd_row21_col0" class="data row21 col0" >8,399 M€</td>
#       <td id="T_334bd_row21_col1" class="data row21 col1" >93 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row22" class="row_heading level0 row22" >Store</th>
#       <th id="T_334bd_level1_row22" class="row_heading level1 row22" >H$_2$ Storage</th>
#       <td id="T_334bd_row22_col0" class="data row22 col0" >6,376 M€</td>
#       <td id="T_334bd_row22_col1" class="data row22 col1" >71 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level0_row23" class="row_heading level0 row23" rowspan="4">Link</th>
#       <th id="T_334bd_level1_row23" class="row_heading level1 row23" >Methanolisation</th>
#       <td id="T_334bd_row23_col0" class="data row23 col0" >5,464 M€</td>
#       <td id="T_334bd_row23_col1" class="data row23 col1" >61 M€</td>
#     </tr>
#     <tr>
#       <th id="T_334bd_level1_row24" class="row_heading l

# %% [markdown]
# Beyond `groupby_method`, the `groupby` parameter itself controls how results are grouped.
# PyPSA provides built-in groupers — `bus`, `bus_carrier`, `carrier`, `country`, `location`, `name`, `unit` — that you can pass as a single string or a list into `groupby`:

# %%
print("Available groupers:", list(pypsa.statistics.groupers.list_groupers().keys()))
# Out:
# Available groupers: ['bus', 'bus_carrier', 'carrier', 'country', 'location', 'name', 'unit']

# %% [markdown]
# Let's say you are interested in the the country allocation of technologies:

# %%
n.statistics.capex(groupby=["country", "carrier"]).to_frame().droplevel(0).unstack()
# Out:
#                     0                                                          \
# carrier Offshore Wind  Onshore Wind  Run Of River         Solar Solar Rooftop
# country
# AL       1.619311e+02  5.086347e+01  1.441856e+07  2.237657e+09  9.150732e+07
# AT                NaN  3.343838e+08  1.379485e+09  2.068363e+09  2.997006e+08
# BA                NaN  9.023051e+06           NaN  1.761479e+08  1.331040e+08
# BE       6.656334e+08  6.420580e+08  2.225603e+07  1.949311e+09  3.900919e+08
# BG       6.876480e+02  7.292283e+07  3.302508e+07  1.949910e+09  2.553665e+08
# CH                NaN  9.117330e+06  1.274669e+09  2.472198e+09  2.697537e+08
# CZ                NaN  3.520131e+07  8.089633e+06  4.625518e+08  3.599586e+08
# DE       4.899651e+09  1.108312e+10  6.703144e+08  7.101399e+09  2.781921e+09
# DK       9.047013e+09  3.046673e+09           NaN  9.523022e+08  1.373034e+08
# EE       8.765108e+02  3.885555e+09           NaN  1.201015e+08  4.028845e+07
# ES       3.111194e+08  1.807216e+10  8.286431e+07  4.531093e+10  1.457498e+09
# EU                NaN           NaN           NaN           NaN           NaN
# FI       1.363568e+07  3.789613e+09  3.959809e+08  1.658624e+07  1.431582e+08
# FR       4.166421e+09  2.097737e+10  1.843034e+09  1.787201e+10  2.159146e+09
# GB       1.855985e+10  1.806679e+10  2.576973e+09  1.139105e+09  2.095918e+09
# GR       5.975289e+03  4.265724e+08  3.084136e+07  8.463431e+09  2.863040e+08
# HR       4.460335e+02  8.175713e+07  6.637922e+07  4.341665e+08  1.339858e+08
# HU                NaN  3.341395e+09  5.893062e+06  3.643640e+08  3.426178e+08
# IE       2.545124e+09  5.846187e+09  3.888823e+07  1.698955e+06  1.454739e+08
# IT       2.645451e+03  4.962873e+09  1.910456e+09  2.618931e+10  1.911785e+09
# LT       2.594505e+03  5.590143e+07  3.021316e+07  6.278169e+06  9.727138e+07
# LU                NaN  1.263834e+08  9.243433e+06  1.089031e+07  2.014047e+07
# LV       1.047808e+03  9.235116e+08  3.876857e+08  1.777499e+08  6.293617e+07
# ME       1.274766e+02  1.223816e+07  1.603392e+06  5.413890e+08  2.428847e+07
# MK                NaN  3.837389e+06           NaN  1.581444e+09  7.025758e+07
# NL       1.130545e+10  1.921088e+09           NaN  1.150731e+09  5.316692e+08
# NO       1.653074e+09  3.320966e+08           NaN  6.435123e+06  9.173883e+07
# PL       7.120517e+08  1.748543e+10  5.385544e+07  1.669543e+08  1.311157e+09
# PT       4.288921e+06  5.407234e+08  7.590683e+08  5.709654e+09  3.030654e+08
# RO       5.103086e+08  3.134753e+08  1.055202e+09  4.393466e+08  6.771891e+08
# RS                NaN  4.117314e+07  5.110512e+08  4.727242e+08  2.473671e+08
# SE       4.663827e+08  1.409268e+10  3.766175e+08  2.242489e+09  3.081378e+08
# SI       1.312220e+02  5.548668e+05  2.684110e+08  1.131810e+07  7.907300e+07
# SK                NaN  3.771267e+05  3.984428e+08  1.180263e+09  1.884745e+08
#
#                                                                              \
# carrier Solar Thermal       Nuclear            AC Air Heat Pump Allam Cycle
# country
# AL       3.290905e+02           NaN  9.223395e+07  2.016588e+07   110.62488
# AT       2.335263e+02           NaN  6.114760e+08  3.808828e+08   117.05790
# BA       2.427680e+02           NaN  1.069885e+08  2.387019e+07   112.99454
# BE       3.010473e+02           NaN  2.653939e+08  1.400220e+09   286.82257
# BG       2.802927e+02  1.470087e+09  2.053906e+08  1.074383e+08   108.24493
# CH       5.080300e+02  2.099115e+09  4.732550e+08  4.149766e+08   120.57817
# CZ       1.599341e+02  1.590238e+09  3.481843e+08  4.495355e+08   112.33190
# DE       2.193377e+03           NaN  2.634123e+09  6.713000e+09  1834.44909
# DK       3.538627e+02           NaN  4.542274e+07  5.921363e+08   233.75338
# EE       1.616019e+02           NaN  3.251613e+07  3.367268e+07    96.90568
# ES       2.010045e+09           NaN  2.408022e+09  2.081017e+09   457.04963
# EU                NaN           NaN           NaN           NaN         NaN
# FI       2.651077e+02  2.381824e+09  2.351972e+08  6.342784e+08   162.02750
# FR       1.488315e+08  1.880015e+09  2.627493e+09  5.468543e+09  1375.09632
# GB       1.347517e+03  7.498857e+08  1.108629e+09  6.526331e+09   968.91444
# GR       8.821554e+02           NaN  5.398392e+07  1.117839e+09   116.00580
# HR       2.382709e+02           NaN  1.859810e+08  2.128870e+08   107.34018
# HU       2.039632e+02  1.342091e+09  1.984695e+08  5.514027e+08   105.88933
# IE       1.455945e+02           NaN           NaN  3.987025e+08    85.92388
# IT       6.650745e+07           NaN  6.813731e+08  5.098686e+09   950.47272
# LT       1.481826e+02           NaN  3.975662e+07  5.915095e+07   111.68558
# LU       1.367028e+02           NaN           NaN  9.226318e+07   128.05950
# LV       1.499674e+02           NaN           NaN  4.831483e+07   116.63151
# ME       3.607387e+02           NaN  2.627206e+07  1.006996e+07   117.24626
# MK       6.446588e+02           NaN  5.229147e+07  1.906692e+07   113.29978
# NL       3.143855e+02           NaN  1.058093e+08  2.064772e+09   280.91712
# NO       4.658359e+02           NaN  4.750567e+08  1.421918e+08   299.18920
# PL       4.765643e+02           NaN  5.868282e+08  1.277885e+09   334.36944
# PT       3.508979e+07           NaN           NaN  2.803734e+08    65.47027
# RO       2.546877e+02  9.188044e+08  1.008444e+08  2.406337e+08   104.28806
# RS       2.788807e+02           NaN           NaN  1.505361e+08   122.73152
# SE       4.456091e+02  6.090260e+09  5.839992e+08  9.205759e+08   267.54071
# SI       1.859063e+02  4.919137e+08           NaN  5.263529e+07   107.67436
# SK       1.723819e+02  1.371139e+09           NaN  1.202245e+08   104.99876
#
#          ...                                                     \
# carrier  ...           DAC Reservoir & Dam Pumped Hydro Storage
# country  ...
# AL       ...           NaN    2.998376e+08                  NaN
# AT       ...           NaN    5.530723e+08         8.945825e+08
# BA       ...           NaN    2.863239e+08         7.803190e+07
# BE       ...           NaN    3.369559e+05         2.319675e+08
# BG       ...           NaN    3.414144e+08         1.532263e+08
# CH       ...           NaN    1.668283e+09         9.508630e+08
# CZ       ...           NaN    1.176863e+08         1.968532e+08
# DE       ...           NaN    3.006001e+07         1.275967e+09
# DK       ...           NaN             NaN                  NaN
# EE       ...           NaN             NaN                  NaN
# ES       ...           NaN    2.508707e+09         1.573185e+09
# EU       ...  1.124051e+10             NaN                  NaN
# FI       ...           NaN    2.023686e+08                  NaN
# FR       ...           NaN    1.138148e+09         7.508796e+08
# GB       ...           NaN    4.048791e+07         7.803190e+07
# GR       ...           NaN    4.550678e+08         1.239643e+08
# HR       ...           NaN    3.306432e+08         4.357372e+07
# HU       ...           NaN    4.965666e+06                  NaN
# IE       ...           NaN    1.773452e+05         6.951932e+07
# IT       ...           NaN    6.967648e+08         1.342840e+09
# LT       ...           NaN             NaN         1.596107e+08
# LU       ...           NaN             NaN         4.579053e+08
# LV       ...           NaN             NaN                  NaN
# ME       ...           NaN    6.117718e+07         5.444498e+07
# MK       ...           NaN             NaN                  NaN
# NL       ...           NaN             NaN                  NaN
# NO       ...           NaN    5.032824e+09         5.006455e+07
# PL       ...           NaN    2.218510e+07         3.188667e+08
# PT       ...           NaN    1.449442e+08         6.567093e+08
# RO       ...           NaN    7.891756e+08                  NaN
# RS       ...           NaN    1.401205e+08         1.088900e+08
# SE       ...           NaN    1.629534e+09         1.631576e+07
# SI       ...           NaN    2.092674e+07         3.192214e+07
# SK       ...           NaN    4.289981e+07         1.458581e+08
#
#                                                                    \
# carrier Battery Storage CO$_2$ Stored           Gas H$_2$ Storage
# country
# AL         2.645567e+08  5.401169e+05  8.062687e+08  7.694978e+01
# AT         4.970618e+02  2.888494e+06  8.063510e+08  1.234827e+02
# BA         6.654751e+02  4.808982e+06  8.063298e+08  9.422994e+01
# BE         6.031467e+02  3.448649e+06  1.612578e+09  1.443950e+02
# BG         7.690234e+07  9.384795e+06  8.062413e+08  8.473501e+01
# CH         6.870825e+02  6.599001e+06  8.062578e+08  1.072673e+02
# CZ         2.554813e+02  1.503753e+06  8.063441e+08  7.430639e+01
# DE         3.814693e+03  3.259533e+07  1.128789e+10  2.090902e+09
# DK         3.610850e+02  1.027926e+02  1.612534e+09  4.718391e+08
# EE         1.883337e+02  1.612808e+05  8.062663e+08  1.115069e+02
# ES         1.104349e+09  5.448688e+07  5.644139e+09  1.183636e+09
# EU                  NaN           NaN           NaN           NaN
# FI         3.399635e+02  3.151841e+06  1.334380e+09  2.570308e+02
# FR         1.773807e+09  5.107388e+07  1.048162e+10  1.068991e+03
# GB         1.922424e+03  2.222604e+06  7.256628e+09  8.942017e+08
# GR         1.108239e+09  3.255580e+06  8.062531e+08  4.922769e+08
# HR         5.380449e+02  1.359873e+06  8.062399e+08  9.951265e+01
# HU         5.339288e+02  4.078818e+06  8.062957e+08  1.007339e+02
# IE         2.161633e+02  2.968719e+03  8.062634e+08  7.171106e+01
# IT         3.996628e+09  2.965764e+07  7.117281e+09  8.802004e+06
# LT         1.723165e+02  4.231061e+06  8.062358e+08  1.015478e+02
# LU         2.583647e+02  5.444883e+04  8.062731e+08  7.482121e+01
# LV         1.790084e+02  4.569293e+01  8.062323e+08  1.090567e+02
# ME         2.591686e+03  7.343531e+06  6.671852e+08  9.213620e+01
# MK         2.053800e+08  5.475843e+06  8.062701e+08  8.805559e+01
# NL         4.938471e+02  1.825038e+07  1.612555e+09  8.782104e+06
# NO         5.034683e+02  7.617872e+06  2.283228e+09  2.804559e+02
# PL         6.459747e+02  1.533124e+07  2.418778e+09  1.145526e+09
# PT         4.377863e+03  3.794149e+06  8.063348e+08  7.961118e+07
# RO         1.387089e+03  1.171188e+07  8.062415e+08  1.019062e+02
# RS         9.072565e+02  1.073609e+07  8.063491e+08  9.268470e+01
# SE         4.802949e+02  3.062579e+06  2.279764e+09  2.836221e+02
# SI         5.109268e+02  4.550779e+06  8.062430e+08  1.048146e+02
# SK         3.771608e+02  5.557532e+06  8.062596e+08  7.609238e+01
#
#
# carrier Home Battery   Water Tanks CO$_2$ Sequestration
# country
# AL         148.11786  7.148896e+06                  NaN
# AT         121.14950  8.851521e+07                  NaN
# BA         176.11678  6.326993e+06                  NaN
# BE         218.57157  9.647287e+07                  NaN
# BG         259.50841  7.693555e+07         2.093717e+06
# CH         118.02738  5.419379e+07                  NaN
# CZ         114.51237  8.579295e+07                  NaN
# DE        1538.13094  5.186327e+08         4.105645e+08
# DK         209.10823  2.614478e+07         1.849939e+08
# EE         115.43291  1.331933e+07         6.523903e+06
# ES         802.37037  1.846030e+08         7.269060e+07
# EU               NaN           NaN                  NaN
# FI         200.94691  5.346013e+07                  NaN
# FR        1796.31819  4.630490e+08                  NaN
# GB        1006.00287  3.171096e+08         2.476299e+08
# GR         159.19343  1.517855e+08         2.193399e+08
# HR         147.50519  2.616482e+07                  NaN
# HU         150.70775  9.541771e+07                  NaN
# IE         111.73445  2.378345e+07         2.249387e+07
# IT        1236.86870  5.361316e+08         2.365347e+08
# LT         108.06158  2.686436e+07         3.632986e+06
# LU         107.70442  5.187609e+06                  NaN
# LV         121.44683  1.297382e+07         2.703104e+08
# ME         177.72727  1.956032e+06                  NaN
# MK         162.20953  3.930224e+06                  NaN
# NL         220.13780  9.048185e+07         4.663114e+07
# NO         333.76746  1.035926e+07         1.341823e+08
# PL         339.52138  1.947246e+08         5.637958e+06
# PT         114.96795  6.668394e+06         5.439285e+07
# RO         286.46977  1.349318e+08                  NaN
# RS         183.49430  2.147235e+07                  NaN
# SE         312.90446  5.387839e+07         8.234747e+07
# SI         126.47139  1.026705e+07                  NaN
# SK         126.61211  2.220479e+07                  NaN
#
# [34 rows x 49 columns]

# %% [markdown]
# # Capacity Analysis
#
# There are three capacity methods:
#
# 1. `installed_capacity` - existing before optimization
# 2. `optimal_capacity` - post-optimization
# 3. `expanded_capacity` - newly built = optimal − installed
#
# in most cases after running an optimization, you want to run the `optimal_capacity` function.
#
#
# Let's have a look:

# %%
caps = n.statistics.optimal_capacity()
caps.to_frame().head(10)
# Out:
#                                     0
# component carrier
# Generator Biomass        9.000000e+05
#           Gas            3.986688e+07
#           Nuclear        2.884290e+04
#           Offshore Wind  2.840745e+05
#           Oil            2.700000e-04
#           Onshore Wind   1.258588e+06
#           Run Of River   4.748597e+04
#           Solar          3.134819e+06
#           Solar Rooftop  5.024461e+05
#           Solar Thermal  1.489607e+05

# %% [markdown]
# :::{note}
# Different components have different capacity types:
#
# | Capacity Type | Components |
# |---|---|
# | Dispatch only | `Generator`, `Link`, `Line`, `Transformer` |
# | Dispatch or storage | `Storage Unit` |
# | Storage only | `Store` |
# :::
#
# Per default, the capacity function return in terms of dispatch capacity. In order to get storage capacities use:

# %%
storage_cap = n.stats.optimal_capacity(storage=True)
storage_cap.to_frame("Capacity").div(1e6).style.format("{:,.0f} TWh")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba26b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba26b_level0_col0" class="col_heading level0 col0" >Capacity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >component</th>
#       <th class="index_name level1" >carrier</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba26b_level0_row0" class="row_heading level0 row0" rowspan="13">Store</th>
#       <th id="T_ba26b_level1_row0" class="row_heading level1 row0" >Battery Storage</th>
#       <td id="T_ba26b_row0_col0" class="data row0 col0" >1 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row1" class="row_heading level1 row1" >Biogas</th>
#       <td id="T_ba26b_row1_col0" class="data row1 col0" >346 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row2" class="row_heading level1 row2" >Biomass</th>
#       <td id="T_ba26b_row2_col0" class="data row2 col0" >1,186 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row3" class="row_heading level1 row3" >CO$_2$</th>
#       <td id="T_ba26b_row3_col0" class="data row3 col0" >35 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row4" class="row_heading level1 row4" >CO$_2$ Sequestration</th>
#       <td id="T_ba26b_row4_col0" class="data row4 col0" >200 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row5" class="row_heading level1 row5" >CO$_2$ Stored</th>
#       <td id="T_ba26b_row5_col0" class="data row5 col0" >1 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row6" class="row_heading level1 row6" >Gas</th>
#       <td id="T_ba26b_row6_col0" class="data row6 col0" >1,024,773 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row7" class="row_heading level1 row7" >H$_2$ Storage</th>
#       <td id="T_ba26b_row7_col0" class="data row7 col0" >61 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row8" class="row_heading level1 row8" >Home Battery</th>
#       <td id="T_ba26b_row8_col0" class="data row8 col0" >0 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row9" class="row_heading level1 row9" >Li Ion</th>
#       <td id="T_ba26b_row9_col0" class="data row9 col0" >6 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row10" class="row_heading level1 row10" >Methanol</th>
#       <td id="T_ba26b_row10_col0" class="data row10 col0" >5,083 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row11" class="row_heading level1 row11" >Oil</th>
#       <td id="T_ba26b_row11_col0" class="data row11 col0" >10,904 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row12" class="row_heading level1 row12" >Water Tanks</th>
#       <td id="T_ba26b_row12_col0" class="data row12 col0" >53 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level0_row13" class="row_heading level0 row13" rowspan="2">StorageUnit</th>
#       <th id="T_ba26b_level1_row13" class="row_heading level1 row13" >Pumped Hydro Storage</th>
#       <td id="T_ba26b_row13_col0" class="data row13 col0" >9 TWh</td>
#     </tr>
#     <tr>
#       <th id="T_ba26b_level1_row14" class="row_heading level1 row14" >Reservoir & Dam</th>
#       <td id="T_ba26b_row14_col0" class="data row14 col0" >207 TWh</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Capacity Factors
#
# Capacity factors relative to the optimal capacity are calculated by the `capacity_factor` function which returns the average operation per unit.

# %%
cf = n.statistics.capacity_factor()
cf.sort_values(ascending=False).dropna()
# Out:
# component  carrier
# Link       Fischer-Tropsch                   9.999999e-01
#            Methanolisation                   9.999998e-01
#            Methanation                       9.999997e-01
#            DAC                               9.999996e-01
#            Biogas To Gas CC                  9.999996e-01
#                                                  ...
#            Biomass-based Industry Process    2.631419e-06
#            Biomass Boiler                    1.004856e-06
#            Gas Boiler                        1.877018e-07
#            Open-Cycle Gas                    1.217680e-07
#            Gas CHP                           4.607652e-08
# Length: 68, dtype: float64

# %% [markdown]
# Now, let's say you want to filter by technologies which produce into the high voltage "AC" electricity-sector. You can do so by setting a `bus_carrier` argument:

# %%
n.statistics.capacity_factor(bus_carrier="AC").to_frame("CF @ AC")
# Out:
#                                                 CF @ AC
# component   carrier
# Generator   Nuclear                        8.283462e-01
#             Offshore Wind                  4.288430e-01
#             Onshore Wind                   2.144537e-01
#             Run Of River                   6.453283e-01
#             Solar                          1.759426e-01
# Line        AC                                      NaN
# Link        Allam Cycle                    1.931906e-01
#             Battery Charger               -2.380275e-01
#             Battery Discharger             2.350337e-01
#             Biomass CHP                    2.903041e-01
#             Biomass CHP CC                 5.957544e-01
#             CO$_2$ Pipeline               -3.660142e-01
#             DAC                           -1.818181e+00
#             DC                            -6.741788e+00
#             Electricity Distribution Grid -6.153618e-01
#             Gas CHP                        1.097060e-07
#             Gas CHP CC                     2.264259e-01
#             Gas Pipeline                  -8.370969e-01
#             H$_2$ Electrolysis            -3.629369e-01
#             H$_2$ Fuel Cell                6.107446e-01
#             H$_2$ Pipeline                -6.693851e+00
#             Methanolisation               -4.200181e+00
#             Open-Cycle Gas                 2.899237e-07
# StorageUnit Pumped Hydro Storage           1.848691e-01
#             Reservoir & Dam                1.130900e-01

# %% [markdown]
# # Energy Flows
#
# Now that we know what's built and what it costs, the next question is: how does energy flow through the system?
#
# - `supply()` / `withdrawal()` — one-directional production / consumption
# - `energy_balance()` — net flow (positive = supply, negative = withdrawal)
# - `transmission()` — energy through branch components (links, lines)
# - `curtailment()` — available generation capacity that went unused

# %%
n.statistics.supply().sort_values(ascending=False).head(10)
# Out:
# component  carrier
# Link       H$_2$ Pipeline                   3.547072e+08
# Line       AC                               3.353883e+08
# Generator  Solar                            2.779804e+08
# Link       Electricity Distribution Grid    2.475761e+08
#            H$_2$ Electrolysis               1.906523e+08
# Generator  Onshore Wind                     1.360341e+08
# Store      H$_2$ Storage                    1.039791e+08
# Link       Fischer-Tropsch                  9.982606e+07
#            Air Heat Pump                    6.951626e+07
# Generator  Offshore Wind                    6.139897e+07
# dtype: float64

# %%
n.statistics.withdrawal().sort_values().head(10)
# Out:
# component  carrier
# Link       Process Emission                   2.95554
#            Open-Cycle Gas                     4.04368
#            Gas CHP                            4.18307
#            SMR                                4.65571
#            Biomass CHP                        5.10219
#            Gas CHP CC                         6.00257
#            Allam Cycle                        6.32064
#            SMR CC                             6.97010
#            Biomass-based Industry Process     7.85956
# Store      Home Battery                      10.20875
# dtype: float64

# %% [markdown]
# `energy_balance` combines both views — positive values mean net supply, negative mean net consumption.
#
# :::{important}
# Unlike other statistics methods, `energy_balance` defaults to `groupby=["carrier", "bus_carrier"]` instead of just `"carrier"`.
# :::

# %%
eb = n.statistics.energy_balance()
eb.head(15)
# Out:
# component  carrier        bus_carrier
# Generator  Biomass        Biomass          7.078587e+06
#            Gas            Gas              2.019385e+07
#            Nuclear        AC               1.204152e+07
#            Offshore Wind  AC               6.139897e+07
#            Oil            Oil              1.317800e-01
#            Onshore Wind   AC               1.360341e+08
#            Run Of River   AC               1.544460e+07
#            Solar          AC               2.779804e+08
#            Solar Rooftop  Low Voltage      4.111438e+07
#            Solar Thermal  Heat             6.351078e+06
# Link       Air Heat Pump  Heat             6.951626e+07
#                           Low Voltage     -2.513954e+07
#            Allam Cycle    AC               3.792390e+00
#                           CO$_2$ Stored    1.264130e+00
#                           Gas             -6.320640e+00
# dtype: float64

# %% [markdown]
# We can use pandas `.xs()` to slice a specific bus carrier. Let's look at the AC electricity sector:

# %%
ac_balance = eb.xs("CO$_2$ Stored", level="bus_carrier")
ac_balance.droplevel(0).sort_values().plot.barh(figsize=(8, 5), xlabel="MWh")
# Out:
# <Axes: xlabel='MWh', ylabel='carrier'>

# %%
n.statistics.transmission()
# Out:
# component  carrier
# Line       AC                 -5.744487e+05
# Link       CO$_2$ Pipeline     2.789895e+07
#            DC                  4.116109e+07
#            Gas Pipeline        4.900522e+07
#            Gas Pipeline New    2.977692e+05
#            H$_2$ Pipeline      3.563951e+08
# dtype: float64

# %%
curt = n.statistics.curtailment()
curt[curt > 0].sort_values(ascending=False)
# Out:
# component    carrier
# Generator    Gas                     2.007271e+10
#              Biomass                 4.465214e+08
# StorageUnit  Reservoir & Dam         4.173515e+07
#              Pumped Hydro Storage    2.925506e+07
# Generator    Solar                   3.722642e+06
#              Onshore Wind            4.774494e+05
#              Nuclear                 3.936798e+05
#              Solar Rooftop           1.669048e+04
#              Offshore Wind           1.061900e+04
#              Run Of River            4.915732e+03
#              Solar Thermal           1.545473e+01
#              Oil                     5.640000e-03
# dtype: float64

# %% [markdown]
# We saw `energy_balance` defaults to `groupby=["carrier", "bus_carrier"]`. Let's try other groupings:

# %%
n.statistics.energy_balance(groupby="bus_carrier")
# Out:
# component    bus_carrier
# Generator    AC                                5.028996e+08
#              Biomass                           7.078587e+06
#              Gas                               2.019385e+07
#              Heat                              6.351078e+06
#              Low Voltage                       4.111438e+07
#              Oil                               1.317800e-01
# Link         AC                               -5.067148e+08
#              Battery Storage                  -1.743546e+05
#              Biogas                           -1.140906e+07
#              Biomass                          -4.993995e+07
#              Biomass-based Industry Process    4.041148e+07
#              CO$_2$                           -2.795097e+07
#              CO$_2$ Sequestration              3.128887e+06
#              CO$_2$ Stored                    -2.386875e+05
#              Gas                               1.082238e+07
#              Gas-based Industry Process        2.193953e+07
#              H$_2$ Storage                     9.368303e+06
#              Heat                              1.095837e+08
#              Home Battery                      1.505000e-02
#              Li Ion                            5.085346e+07
#              Low Voltage                       1.541408e+08
#              Methanol                          3.913717e+07
#              Oil                               8.406405e+07
#              Process Emission                 -8.785479e+06
#              Water Tanks                       2.856458e+06
# Load         Biomass-based Industry Process   -4.041148e+07
#              CO$_2$                            2.768283e+07
#              Gas-based Industry Process       -2.193953e+07
#              H$_2$ Storage                    -1.126348e+07
#              Heat                             -1.159348e+08
#              Li Ion                           -5.113294e+07
#              Low Voltage                      -1.952552e+08
#              Methanol                         -3.143468e+07
#              Oil                              -8.211470e+07
#              Process Emission                  8.785479e+06
# StorageUnit  AC                                3.815262e+06
# Store        Battery Storage                   1.743546e+05
#              Biogas                            1.140906e+07
#              Biomass                           4.286136e+07
#              CO$_2$                            2.681409e+05
#              CO$_2$ Sequestration             -3.128887e+06
#              CO$_2$ Stored                     2.386875e+05
#              Gas                              -3.101622e+07
#              H$_2$ Storage                     1.895177e+06
#              Home Battery                     -1.505000e-02
#              Li Ion                            2.794813e+05
#              Methanol                         -7.702488e+06
#              Oil                              -1.949353e+06
#              Water Tanks                      -2.856458e+06
# dtype: float64

# %% [markdown]
# Use `components` to restrict which component types are included:

# %%
n.statistics.supply(components="Generator").head(10)
# Out:
# carrier
# Biomass          7.078587e+06
# Gas              2.019385e+07
# Nuclear          1.204152e+07
# Offshore Wind    6.139897e+07
# Oil              1.317800e-01
# Onshore Wind     1.360341e+08
# Run Of River     1.544460e+07
# Solar            2.779804e+08
# Solar Rooftop    4.111438e+07
# Solar Thermal    6.351078e+06
# dtype: float64

# %% [markdown]
# Set `groupby_time=False` to get a full time series (MW per snapshot) instead of a single aggregated value.
# You can also use `groupby_time="mean"` for average MW or `groupby_time="sum"` (default) for total MWh:

# %%
ts = n.statistics.energy_balance(groupby_time=False)
print(f"Shape: {ts.shape} — rows are (component, carrier), columns are timestamps")
ts.iloc[:5, :5]
# Out:
# Shape: (161, 168) — rows are (component, carrier), columns are timestamps
# snapshot                             2013-05-01 00:00:00  2013-05-01 03:00:00  \
# component carrier       bus_carrier
# Generator Biomass       Biomass              13920.68276          13939.92892
#           Gas           Gas                  39747.40024          39810.28518
#           Heat Waste    Heat                         NaN                  NaN
#           Nuclear       AC                   24673.01241          24673.01247
#           Offshore Wind AC                   83202.06897          74670.49170
#
# snapshot                             2013-05-01 06:00:00  2013-05-01 09:00:00  \
# component carrier       bus_carrier
# Generator Biomass       Biomass              13988.90637          14004.15125
#           Gas           Gas                  39879.16306          39931.35482
#           Heat Waste    Heat                         NaN                  NaN
#           Nuclear       AC                   21631.79378          21631.79244
#           Offshore Wind AC                   69537.54671          63503.76714
#
# snapshot                             2013-05-01 12:00:00
# component carrier       bus_carrier
# Generator Biomass       Biomass              14001.86514
#           Gas           Gas                  39960.20755
#           Heat Waste    Heat                         NaN
#           Nuclear       AC                   21631.79507
#           Offshore Wind AC                   66552.69901

# %%
pd.concat([
    n.statistics.energy_balance(groupby_time="mean").rename("mean (MW)"),
    n.statistics.energy_balance(groupby_time="sum").rename("sum (MWh)"),
], axis=1).head(10).style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_11cf5">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11cf5_level0_col0" class="col_heading level0 col0" >mean (MW)</th>
#       <th id="T_11cf5_level0_col1" class="col_heading level0 col1" >sum (MWh)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >component</th>
#       <th class="index_name level1" >carrier</th>
#       <th class="index_name level2" >bus_carrier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11cf5_level0_row0" class="row_heading level0 row0" rowspan="10">Generator</th>
#       <th id="T_11cf5_level1_row0" class="row_heading level1 row0" >Biomass</th>
#       <th id="T_11cf5_level2_row0" class="row_heading level2 row0" >Biomass</th>
#       <td id="T_11cf5_row0_col0" class="data row0 col0" >14,045</td>
#       <td id="T_11cf5_row0_col1" class="data row0 col1" >7,078,587</td>
#     </tr>
#     <tr>
#       <th id="T_11cf5_level1_row1" class="row_heading level1 row1" >Gas</th>
#       <th id="T_11cf5_level2_row1" class="row_heading level2 row1" >Gas</th>
#       <td id="T_11cf5_row1_col0" class="data row1 col0" >40,067</td>
#       <td id="T_11cf5_row1_col1" class="data row1 col1" >20,193,846</td>
#     </tr>
#     <tr>
#       <th id="T_11cf5_level1_row2" class="row_heading level1 row2" >Nuclear</th>
#       <th id="T_11cf5_level2_row2" class="row_heading level2 row2" >AC</th>
#       <td id="T_11cf5_row2_col0" class="data row2 col0" >23,892</td>
#       <td id="T_11cf5_row2_col1" class="data row2 col1" >12,041,521</td>
#     </tr>
#     <tr>
#       <th id="T_11cf5_level1_row3" class="row_heading level1 row3" >Offshore Wind</th>
#       <th id="T_11cf5_level2_row3" class="row_heading level2 row3" >AC</th>
#       <td id="T_11cf5_row3_col0" class="data row3 col0" >121,823</td>
#       <td id="T_11cf5_row3_col1" class="data row3 col1" >61,398,971</td>
#     </tr>
#     <tr>
#       <th id="T_11cf5_level1_row4" class="row_heading level1 row4" >Oil</th>
#       <th id="T_11cf5_level2_row4" class="row_heading level2 row4" >Oil</th>
#       <td id="T_11cf5_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_11cf5_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_11cf5_level1_row5" class="row_heading level1 row5" >Onshore Wind</th>
#       <th id="T_11cf5_level2_row5" class="row_heading level2 row5" >AC</th>
#       <td id="T_11cf5_row5_col0" class="data row5 col0" >269,909</td>
#       <td id="T_11cf5_row5_col1" class="data row5 col1" >136,034,098</td>
#     </tr>
#     <tr>
#       <th id="T_11cf5_level1_row6" class="row_heading level1 row6" >Run Of River</th>
#       <th id="T_11cf5_level2_row6" class="row_heading level2 row6" >AC</th>
#       <td id="T_11cf5_row6_col0" class="data row6 col0" >30,644</td>
#       <td id="T_11cf5_row6_col1" class="data row6 col1" >15,444,596</td>
#     </tr>
#     <tr>
#       <th id="T_11cf5_level1_row7" class="row_heading level1 row7" >Solar</th>
#       <th id="T_11cf5_level2_row7" class="row_heading level2 row7" >AC</th>
#       <td id="T_11cf5_row7_col0" class="data row7 col0" >551,548</td>
#       <td id="T_11cf5_row7_col1" class="data row7 col1" >277,980,369</td>
#     </tr>
#     <tr>
#       <th id="T_11cf5_level1_row8" class="row_heading level1 row8" >Solar Rooftop</th>
#       <th id="T_11cf5_level2_row8" class="row_heading level2 row8" >Low Voltage</th>
#       <td id="T_11cf5_row8_col0" class="data row8 col0" >81,576</td>
#       <td id="T_11cf5_row8_col1" class="data row8 col1" >41,114,382</td>
#     </tr>
#     <tr>
#       <th id="T_11cf5_level1_row9" class="row_heading level1 row9" >Solar Thermal</th>
#       <th id="T_11cf5_level2_row9" class="row_heading level2 row9" >Heat</th>
#       <td id="T_11cf5_row9_col0" class="data row9 col0" >12,601</td>
#       <td id="T_11cf5_row9_col1" class="data row9 col1" >6,351,078</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Market Metrics
#
# Now that we understand physical flows, we can look at the economic side:
#
# - `prices()` — marginal prices per bus (shadow prices of the energy balance constraint)
# - `revenue()` — income earned by each carrier
# - `market_value()` — revenue per unit of energy (€/MWh), i.e. the average price a technology receives

# %%
prices = n.statistics.prices(groupby="bus_carrier")
print(f"Mean electricity price: {prices.mean():.2f} €/MWh")
prices.plot.barh(figsize=(6, 6), edgecolor="white", xlabel="€/MWh", ylabel="Bus Carrier")
# Out:
# Mean electricity price: -31.33 €/MWh
# <Axes: xlabel='€/MWh', ylabel='Bus Carrier'>

# %%
n.statistics.revenue().sort_values(ascending=False).head(10)
# Out:
# component  carrier
# Generator  Solar                   5.663771e+09
#            Onshore Wind            3.728815e+09
# Store      Biomass                 3.465139e+09
# Link       Fischer-Tropsch         3.193419e+09
# Generator  Offshore Wind           1.678349e+09
# Link       Methanolisation         1.492719e+09
#            H$_2$ Electrolysis      1.230513e+09
#            DAC                     1.010560e+09
# Generator  Solar Rooftop           9.931851e+08
# Store      CO$_2$ Sequestration    7.348046e+08
# dtype: float64

# %% [markdown]
# :::{tip}
# `market_value` = revenue / supply — the average price a carrier receives per MWh. Technologies with high output during low-price hours tend to have lower market values.
# :::

# %%
n.statistics.market_value().sort_values(ascending=False).head(10)
# Out:
# component    carrier
# Link         DAC                    128.337960
# Generator    Biomass                 94.235825
# Link         Biogas To Gas CC        50.345207
#              Biogas To Gas           38.093796
#              Methanolisation         33.514237
# StorageUnit  Reservoir & Dam         31.089968
# Link         Fischer-Tropsch         30.390340
#              Process Emission CC     30.064540
# Generator    Nuclear                 28.606267
#              Onshore Wind            27.410886
# dtype: float64

# %% [markdown]
# # Custom Groupers
#
# Register a custom grouper via `groupers.add_grouper(name, func)`.
#
# :::{note}
# The function signature is `(n, c, port) -> pd.Series` where `n` is the network, `c` the component name, and `port` the port suffix (empty for single-port components).
# :::

# %%
from pypsa.statistics import groupers
def tech_type(n, c, port=""):
    carriers = n.c[c].static["carrier"]
    nice_names = carriers.map(n.carriers.nice_name)
    conditions = {
        "Renewable": ["wind", "solar", "ror", "hydro"],
        "Conventional": ["gas", "oil", "nuclear"],
        "Storage": ["battery", "storage", "reservoir"],
    }
    def classify(name):
        lower = name.lower()
        for label, keywords in conditions.items():
            if any(kw in lower for kw in keywords):
                return label
        return "Other"
    return nice_names.map(classify).rename("tech_type")

groupers.add_grouper("tech_type", tech_type)

# %%
n.statistics.capex(groupby="tech_type")
# Out:
# component    tech_type
# Generator    Conventional    2.038537e+10
#              Other           1.420496e+10
#              Renewable       3.380796e+11
# Line         Other           1.428499e+10
# Link         Conventional    4.060287e+10
#              Other           1.994947e+11
#              Storage         2.816050e+09
# StorageUnit  Renewable       9.764073e+09
#              Storage         1.655813e+10
# Store        Conventional    7.173411e+10
#              Other           5.729826e+09
#              Storage         1.490548e+10
# dtype: float64

# %%
n.statistics.supply(groupby=["tech_type", "carrier"], aggregate_across_components=True).to_frame("Supply").head(70)
# Out:
#                                             Supply
# tech_type    carrier
# Conventional Biogas                   1.140906e+07
#              Biogas To Gas            3.793597e+01
#              Biogas To Gas CC         1.233315e+07
#              Biomass Boiler           1.721489e+01
#              Gas                      5.373954e+07
# ...                                            ...
# Storage      H$_2$ Storage            1.039791e+08
#              Home Battery             1.019370e+01
#              Home Battery Charger     1.490037e+02
#              Home Battery Discharger  1.459785e+02
#              Reservoir & Dam          5.321654e+06
#
# [67 rows x 1 columns]

# %% [markdown]
# :::{tip} Tips and tricks
# - Use `s = n.statistics` in the beginning of your code; then `s.capex(**kwargs)` is very compact
# - Set `aggregate_across_components=True` if you have distinct carriers
# - Specify `bus_carrier` if you deal with sector-coupled networks, so you don't mix units — especially useful for multi-port links
# - group by `unit`
# :::

# %% [markdown]
# ## Recap
#
# | Category | Methods |
# |---|---|
# | **Costs** | `capex()`, `installed_capex()`, `expanded_capex()`, `opex()`, `system_cost()` |
# | **Capacity** | `installed_capacity()`, `optimal_capacity()`, `expanded_capacity()`, `capacity_factor()` |
# | **Energy** | `supply()`, `withdrawal()`, `energy_balance()`, `transmission()`, `curtailment()` |
# | **Market** | `prices()`, `revenue()`, `market_value()` |
# | **Overview** | `n.statistics()` (summary table) |
# | **Plotting** | `.plot.bar()`, `.iplot.area()`, etc. on every method |
#
# Key parameters: `groupby`, `groupby_method`, `groupby_time`, `components`, `carrier`, `bus_carrier`, `nice_names`.
#
# :::{seealso}
# Full documentation: [pypsa.org/latest/user-guide/statistics](https://docs.pypsa.org/latest/user-guide/statistics/)
# :::

# %% [markdown]
# :::{dropdown} Spoiler: Plotting from Statistics (next session)
# Every statistics method has `.plot` (matplotlib/seaborn) and `.iplot` (plotly) accessors.
# All statistics parameters (`carrier`, `bus_carrier`, `groupby`, ...) pass through — no need to query first and plot separately.
#
# Available plot types: `bar`, `line`, `area`, `box`, `scatter`, `histogram`, `violin`, `chart`, `map`.
# :::

# %%
carriers = ["solar", "onwind", "offwind"]
n.statistics.optimal_capacity.iplot.bar(carrier=carriers)

# %% [markdown]
# All statistics parameters pass through. For example, filter by `carrier`:

# %%
n.statistics.supply.iplot.bar(carrier=carriers)

# %% [markdown]
# For interactive plots, use `.iplot` (plotly) instead of `.plot` (matplotlib):

# %%
n.statistics.energy_balance.iplot.area(carrier=carriers)

# %%
n.statistics.energy_balance.plot.map(bus_carrier=["AC"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 n.statistics.energy_balance.plot.map(bus_carrier=["AC"])
#
# File ~/vres/py/oet/pypsa-training-sessions/.venv/lib/python3.12/site-packages/pypsa/common.py:544, in deprecated_kwargs.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     539 @functools.wraps(f)
#     540 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     541     rename_deprecated_kwargs(
#     542         f.__name__, kwargs, aliases, deprecated_in, removed_in
#     543     )
# --> 544     return f(*args, **kwargs)
#
# File ~/vres/py/oet/pypsa-training-sessions/.venv/lib/python3.12/site-packages/pypsa/plot/statistics/plotter.py:542, in StatisticPlotter.map(self, ax, projection, geomap, geomap_resolution, geomap_color, boundaries, title, bus_carrier, carrier, transmission_flow, bus_area_fraction, branch_area_fraction, flow_area_fraction, draw_legend_circles, draw_legend_lines, draw_legend_arrows, draw_legend_patches, legend_circles_kw, legend_lines_kw, legend_arrows_kw, legend_patches_kw, bus_split_circle, storage, **kwargs)
#     537 stats_kwargs = apply_parameter_schema(stats_name, "map", {"storage": storage})
#     539 # Note that instead of passing the data to the plotter, we pass the
#     540 # statistics function. This gives the map plotter the ability to
#     541 # determine the data for buses and branches itself.
# --> 542 return plotter.plot(
#     543     func=self._bound_method, **plot_kwargs, stats_kwargs=stats_kwargs, **kwargs
#     544 )
#
# File ~/vres/py/oet/pypsa-training-sessions/.venv/lib/python3.12/site-packages/pypsa/common.py:544, in deprecated_kwargs.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     539 @functools.wraps(f)
#     540 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     541     rename_deprecated_kwargs(
#     542         f.__name__, kwargs, aliases, deprecated_in, removed_in
#     543     )
# --> 544     return f(*args, **kwargs)
#
# File ~/vres/py/oet/pypsa-training-sessions/.venv/lib/python3.12/site-packages/pypsa/plot/statistics/maps.py:139, in MapPlotGenerator.plot(self, func, bus_carrier, ax, projection, geomap, geomap_resolution, geomap_color, boundaries, title, carrier, groupby, transmission_flow, bus_area_fraction, branch_area_fraction, flow_area_fraction, draw_legend_circles, draw_legend_lines, draw_legend_arrows, draw_legend_patches, legend_circles_kw, legend_lines_kw, legend_arrows_kw, legend_patches_kw, bus_split_circle, stats_kwargs, nice_names, **kwargs)
#     133 with warnings.catch_warnings():
#     134     warnings.filterwarnings(
#     135         "ignore",
#     136         message=".*Passing `aggregate_across_components` was deprecated.*",
#     137         category=DeprecationWarning,
#     138     )
# --> 139     bus_size = func(
#     140         bus_carrier=bus_carrier,
#     141         groupby=groupby,
#     142         carrier=list(non_transmission_carriers),
#     143         nice_names=False,
#     144         aggregate_across_components=True,
#     145         **(stats_kwargs or {}),
#     146     )
#     147 if bus_size.empty:
#     148     # TODO: this fallback case should be handled in the statistics function
#     149     bus_size = (
#     150         pd.DataFrame({"bus": [], "carrier": [], "value": []})
#     151         .set_index(["bus", "carrier"])
#     152         .value
#     153     )
#
# File ~/vres/py/oet/pypsa-training-sessions/.venv/lib/python3.12/site-packages/pypsa/common.py:544, in deprecated_kwargs.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     539 @functools.wraps(f)
#     540 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     541     rename_deprecated_kwargs(
#     542         f.__name__, kwargs, aliases, deprecated_in, removed_in
#     543     )
# --> 544     return f(*args, **kwargs)
#
# File ~/vres/py/oet/pypsa-training-sessions/.venv/lib/python3.12/site-packages/pypsa/statistics/expressions.py:2295, in StatisticsAccessor.energy_balance(self, components, groupby_time, groupby_method, aggregate_across_components, groupby, at_port, carrier, bus_carrier, nice_names, drop_zero, round, direction)
#    2280 df = self._aggregate_components(
#    2281     func,
#    2282     components=components,
#    (...)   2291     round=round,
#    2292 )
#    2294 df.attrs["name"] = "Energy Balance"
# -> 2295 df.attrs["unit"] = n.bus_carrier_unit(bus_carrier)
#    2296 return df
#
# File ~/vres/py/oet/pypsa-training-sessions/.venv/lib/python3.12/site-packages/pypsa/network/descriptors.py:272, in NetworkDescriptorsMixin.bus_carrier_unit(self, bus_carrier)
#     270     logger.warning("Multiple units found for carrier %s: %s", bus_carrier, unit)
#     271     return "carrier dependent"
# --> 272 return unit.item()
#
# AttributeError: 'StringArray' object has no attribute 'item'
